# %%
import pandas as pd

# %%
data3= 'data/data_3file.csv'
gd = pd.read_csv(data3)
gd
# Out:
#          Unnamed: 0  site_id  building_id primary_use  square_feet  \
# 0                 0        0          0.0   Education       7432.0
# 1                 1        0          1.0   Education       2720.0
# 2                 2        0          2.0   Education       5376.0
# 3                 3        0          3.0   Education      23685.0
# 4                 4        0          4.0   Education     116607.0
# ...             ...      ...          ...         ...          ...
# 8990170     8990170        7        803.0   Education     182986.0
# 8990171     8990171        7        789.0   Education      64583.0
# 8990172     8990172        7        789.0   Education      64583.0
# 8990173     8990173        7        790.0   Education      86111.0
# 8990174     8990174        7        790.0   Education      86111.0
#
#          year_built  floor_count            timestamp  meter_reading  \
# 0            2008.0          NaN  2016-01-01 00:00:00           0.00
# ...
